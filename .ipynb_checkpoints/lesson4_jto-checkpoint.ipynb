# %%
import tensorflow as tf
#gpu_options = tf.GPUOptions(per_process_gpu_memory_fraction=0.3333)
#sess = tf.Session(config=tf.ConfigProto(gpu_options=gpu_options))

config = tf.ConfigProto()
config.gpu_options.allow_growth=True
sess = tf.Session(config=config)

import os
os.environ["CUDA_DEVICE_ORDER"]='PCI_BUS_ID'
os.environ["CUDA_VISIBLE_DEVICES"]='2'

import keras
from keras.models import Model
from keras.layers.normalization import BatchNormalization
from keras.layers.core import Dense, Lambda, Flatten, Dropout
from keras.optimizers import Adam, sgd
from keras.layers import Input, Embedding, Reshape, merge, LSTM, Bidirectional
from keras.layers.embeddings import Embedding
from keras.regularizers import l1, l2

import pandas as pd
import numpy as np

#if 'session' in locals() and session is not None:
#    print('Close interactive session')
#    session.close()

path = "D:\\jtownend\\fast.ai\\data\\movielens\\"

# %%
ratings = pd.read_csv(path+'ratings.csv')
movie_names = pd.read_csv(path+'movies.csv').set_index('movieId')['title'].to_dict()

users = ratings.userId.unique()
movies = ratings.movieId.unique()
n_users = ratings.userId.nunique()
n_movies = ratings.movieId.nunique()

#replace the user and movie IDs with contiguous integers
userid2idx = {o:i for i,o in enumerate(users)}
movieid2idx = {o:i for i,o in enumerate(movies)}
ratings.movieId = ratings.movieId.apply(lambda x: movieid2idx[x])
ratings.userId = ratings.userId.apply(lambda x: userid2idx[x])

#divide randomly into train and validation sets
np.random.seed = 42
msk = np.random.rand(len(ratings)) < 0.8
trn = ratings[msk]
val = ratings[~msk]

#set number of latent factors
n_factors = 50

# %% [markdown]
# ## Dot product

# %%
user_in = Input(shape=(1,), dtype='int64', name='user_in')
u = Embedding(n_users, n_factors, input_length=1, W_regularizer=l2(1e-4))(user_in)
movie_in = Input(shape=(1,), dtype='int64', name='movie_in')
m = Embedding(n_movies, n_factors, input_length=1, W_regularizer=l2(1e-4))(movie_in)

x = merge([u, m], mode='dot')
x = Flatten()(x)
model = Model([user_in, movie_in], x)
model.compile(loss='mse', optimizer=Adam(0.01), metrics=['accuracy'])

# %%
model.fit([trn.userId, trn.movieId], trn.rating, batch_size=64, nb_epoch=4, 
          validation_data=([val.userId, val.movieId], val.rating))
# Out:
# Train on 80084 samples, validate on 19920 samples
# Epoch 1/4
# 80084/80084 [==============================] - 6s - loss: 2.9582 - acc: 0.2762 - val_loss: 3.5573 - val_acc: 0.2539
# Epoch 2/4
# 80084/80084 [==============================] - 6s - loss: 2.8840 - acc: 0.2828 - val_loss: 3.4992 - val_acc: 0.2536
# Epoch 3/4
# 80084/80084 [==============================] - 6s - loss: 2.8227 - acc: 0.2906 - val_loss: 3.4855 - val_acc: 0.2560
# Epoch 4/4
# 80084/80084 [==============================] - 7s - loss: 2.7775 - acc: 0.2928 - val_loss: 3.4578 - val_acc: 0.2556

# %%
model.optimizer.lr=0.001

# %%
model.fit([trn.userId, trn.movieId], trn.rating, batch_size=64, nb_epoch=3, 
          validation_data=([val.userId, val.movieId], val.rating))
# Out:
# Train on 80084 samples, validate on 19920 samples
# Epoch 1/3
# 80084/80084 [==============================] - 6s - loss: 2.7462 - acc: 0.2954 - val_loss: 3.4222 - val_acc: 0.2560
# Epoch 2/3
# 80084/80084 [==============================] - 6s - loss: 2.7214 - acc: 0.2973 - val_loss: 3.4220 - val_acc: 0.2559
# Epoch 3/3
# 80084/80084 [==============================] - 6s - loss: 2.7115 - acc: 0.2976 - val_loss: 3.4147 - val_acc: 0.2596

# %% [markdown]
# ## Introduce bias to improve result

# %%
def embedding_input(name, n_in, n_out, reg):
    inp = Input(shape=(1,), dtype='int64', name=name)
    return inp, Embedding(n_in, n_out, input_length=1, W_regularizer=l2(reg))(inp)

def create_bias(inp, n_in):
    x = Embedding(n_in, 1, input_length=1)(inp)
    return Flatten()(x)

# %%
user_in, u = embedding_input('user_in', n_users, n_factors, 1e-4)
movie_in, m = embedding_input('movie_in', n_movies, n_factors, 1e-4)

ub = create_bias(user_in, n_users)
mb = create_bias(movie_in, n_movies)

# %%
x = merge([u, m], mode='dot')
x = Flatten()(x)
x = merge([x, ub], mode='sum')
x = merge([x, mb], mode='sum')
model = Model([user_in, movie_in], x)
model.compile(Adam(0.001), loss='mse')

# %%
model.fit([trn.userId, trn.movieId], trn.rating, batch_size=64, nb_epoch=1, 
          validation_data=([val.userId, val.movieId], val.rating))
# Out:
# Train on 80084 samples, validate on 19920 samples
# Epoch 1/1
# 80084/80084 [==============================] - 8s - loss: 8.7690 - val_loss: 3.4730

# %%
model.optimizer.lr=0.02

# %%
model.fit([trn.userId, trn.movieId], trn.rating, batch_size=64, nb_epoch=6, 
          validation_data=([val.userId, val.movieId], val.rating))
# Out:
# Train on 80084 samples, validate on 19920 samples
# Epoch 1/6
# 80084/80084 [==============================] - 7s - loss: 0.5724 - val_loss: 1.0303
# Epoch 2/6
# 80084/80084 [==============================] - 7s - loss: 0.5656 - val_loss: 1.0280
# Epoch 3/6
# 80084/80084 [==============================] - 7s - loss: 0.5592 - val_loss: 1.0261
# Epoch 4/6
# 80084/80084 [==============================] - 7s - loss: 0.5545 - val_loss: 1.0246
# Epoch 5/6
# 80084/80084 [==============================] - 7s - loss: 0.5502 - val_loss: 1.0239
# Epoch 6/6
# 80084/80084 [==============================] - 7s - loss: 0.5467 - val_loss: 1.0238

# %%
model.optimizer.lr=0.001

# %%
model.fit([trn.userId, trn.movieId], trn.rating, batch_size=64, nb_epoch=6, 
          validation_data=([val.userId, val.movieId], val.rating))
# Out:
# Train on 80084 samples, validate on 19920 samples
# Epoch 1/6
# 80084/80084 [==============================] - 7s - loss: 0.5437 - val_loss: 1.0240
# Epoch 2/6
# 80084/80084 [==============================] - 7s - loss: 0.5414 - val_loss: 1.0245
# Epoch 3/6
# 80084/80084 [==============================] - 7s - loss: 0.5392 - val_loss: 1.0252
# Epoch 4/6
# 80084/80084 [==============================] - 6s - loss: 0.5373 - val_loss: 1.0262
# Epoch 5/6
# 80084/80084 [==============================] - 7s - loss: 0.5355 - val_loss: 1.0263
# Epoch 6/6
# 80084/80084 [==============================] - 7s - loss: 0.5342 - val_loss: 1.0270

# %%
model.save_weights("D:\\jtownend\\fast.ai\\data\\movielens\\movielens-bias.h5")

# %%
model.load_weights("D:\\jtownend\\fast.ai\\data\\movielens\\movielens-bias.h5")

# %%
model.predict([np.array([3]), np.array([6])])
# Out:
# array([[ 4.78690624]], dtype=float32)

# %% [markdown]
# ## Analyze results

# %%
#get top 2000 most popular movies
g=ratings.groupby('movieId')['rating'].count()
topMovies=g.sort_values(ascending=False)[:2000]
topMovies = np.array(topMovies.index)

# %%
#set up another "model" with input of a movie and output of the movie bias (not sure how this works! where are the biases from?)
get_movie_bias = Model(movie_in, mb)
movie_bias = get_movie_bias.predict(topMovies)
movie_ratings = [(b[0], movie_names[movies[i]]) for i,b in zip(topMovies,movie_bias)]

# %%
movie_ratings
# Out:
# [(1.4195137, 'Forrest Gump (1994)'),
#  (1.4857801, 'Pulp Fiction (1994)'),
#  (1.8113035, 'Shawshank Redemption, The (1994)'),
#  (1.5332462, 'Silence of the Lambs, The (1991)'),
#  (1.4902164, 'Star Wars: Episode IV - A New Hope (1977)'),
#  (1.1075996, 'Jurassic Park (1993)'),
#  (1.4778115, 'Matrix, The (1999)'),
#  (1.2142898, 'Toy Story (1995)'),
#  (1.6278839, "Schindler's List (1993)"),
#  (1.2836015, 'Terminator 2: Judgment Day (1991)'),
#  (1.4696461, 'Star Wars: Episode V - The Empire Strikes Back (1980)'),
#  (1.3274693, 'Braveheart (1995)'),
#  (1.307214, 'Back to the Future (1985)'),
#  (1.5374744, 'Fargo (1996)'),
#  (1.4403865,
#   'Raiders of the Lost Ark (Indiana Jones and the Raiders of the Lost Ark) (1981)'),
#  (1.4808617, 'American Beauty (1999)'),
#  (0.86855781, 'Independence Day (a.k.a. ID4) (1996)'),
#  (1.2844898, 'Star Wars: Episode VI - Return of the Jedi (1983)'),
#  (0.97603464, 'Aladdin (1992)'),
#  (1.3020918, 'Fugitive, The (1993)'),
#  (1.4781756, 'Fight Club (1999)'),
#  (1.061716, 'Dances with Wolves (1990)'),
#  (1.32752, 'Seven (a.k.a. Se7en) (1995)'),
#  (1.6068685, 'Usual Suspects, The (1995)'),
#  (1.1372185, 'Lion King, The (1994)'),
#  (1.7198647, 'Godfather, The (1972)'),
#  (1.4512829, 'Lord of the Rings: The Fellowship of the Ring, The (2001)'),
#  (1.2516944, 'Apollo 13 (1995)'),
#  (0.93719524, 'True Lies (1994)'),
#  (0.77505767, 'Batman (1989)'),
#  (1.2306767, 'Twelve Monkeys (a.k.a. 12 Monkeys) (1995)'),
#  (1.3854792, 'Sixth Sense, The (1999)'),
#  (1.25876, 'Saving Private Ryan (1998)'),
#  (1.0653306, 'Men in Black (a.k.a. MIB) (1997)'),
#  (1.3782445, 'Lord of the Rings: The Two Towers, The (2002)'),
#  (0.92483366, 'Speed (1994)'),
#  (1.0916165, 'Beauty and the Beast (1991)'),
#  (1.4225512, 'Lord of the Rings: The Return of the King, The (2003)'),
#  (0.34990105, 'Ace Ventura: Pet Detective (1994)'),
#  (1.2369164, 'Shrek (2001)'),
#  (0.90873766, 'Mission: Impossible (1996)'),
#  (1.1473478, 'Groundhog Day (1993)'),
#  (0.75687987, 'Titanic (1997)'),
#  (1.4456856, 'Princess Bride, The (1987)'),
#  (1.2873799, 'Gladiator (2000)'),
#  (1.0898499, 'E.T. the Extra-Terrestrial (1982)'),
#  (1.2590867, 'Terminator, The (1984)'),
#  (0.45168191, 'Dumb & Dumber (Dumb and Dumber) (1994)'),
#  (0.54795676, 'Mask, The (1994)'),
#  (1.4346132, 'Good Will Hunting (1997)'),
#  (0.88072711, 'Mrs. Doubtfire (1993)'),
#  (1.2336302, 'Die Hard (1988)'),
#  (0.72261792, 'Twister (1996)'),
#  (0.8871249, 'Babe (1995)'),
#  (1.0582516, 'Willy Wonka & the Chocolate Factory (1971)'),
#  (1.1275882, 'Ghostbusters (a.k.a. Ghost Busters) (1984)'),
#  (0.81609845, 'Pretty Woman (1990)'),
#  (1.4104888, 'Indiana Jones and the Last Crusade (1989)'),
#  (1.3279895, 'Blade Runner (1982)'),
#  (1.5256207, 'Monty Python and the Holy Grail (1975)'),
#  (0.75683582, 'Stargate (1994)'),
#  (1.5835106, "One Flew Over the Cuckoo's Nest (1975)"),
#  (0.78795481, 'Die Hard: With a Vengeance (1995)'),
#  (1.1982225, 'Pirates of the Caribbean: The Curse of the Black Pearl (2003)'),
#  (0.54213977, 'Star Wars: Episode I - The Phantom Menace (1999)'),
#  (1.2641438, 'Truman Show, The (1998)'),
#  (1.6759725, 'Godfather: Part II, The (1974)'),
#  (1.094551, 'Rock, The (1996)'),
#  (0.87553245, 'Spider-Man (2002)'),
#  (1.2838956, "Ferris Bueller's Day Off (1986)"),
#  (1.4000992, 'Reservoir Dogs (1992)'),
#  (1.5950117, 'Memento (2000)'),
#  (1.4437999, 'Léon: The Professional (a.k.a. The Professional) (Léon) (1994)'),
#  (1.3434886, 'Goodfellas (1990)'),
#  (1.2688991, "Ocean's Eleven (2001)"),
#  (1.2196841, 'Monsters, Inc. (2001)'),
#  (0.61295676, 'Home Alone (1990)'),
#  (0.27843589, 'Batman Forever (1995)'),
#  (1.1795313, 'Alien (1979)'),
#  (0.93689179, 'X-Men (2000)'),
#  (1.2070606, 'Incredibles, The (2004)'),
#  (1.2313703, 'Being John Malkovich (1999)'),
#  (0.78489769, 'Ghost (1990)'),
#  (1.1784998, 'Aliens (1986)'),
#  (0.77727908, 'Interview with the Vampire: The Vampire Chronicles (1994)'),
#  (1.1525407, 'Toy Story 2 (1999)'),
#  (1.3287262, "Amelie (Fabuleux destin d'Amélie Poulain, Le) (2001)"),
#  (0.83080715, 'Sleepless in Seattle (1993)'),
#  (1.3244196, 'L.A. Confidential (1997)'),
#  (1.3174524, 'Trainspotting (1996)'),
#  (0.91226405, "There's Something About Mary (1998)"),
#  (1.2248476, '2001: A Space Odyssey (1968)'),
#  (0.87445009, 'GoldenEye (1995)'),
#  (1.2753783, 'Finding Nemo (2003)'),
#  (1.0616952, 'Four Weddings and a Funeral (1994)'),
#  (1.2544398, 'Clockwork Orange, A (1971)'),
#  (1.2852157, 'Shakespeare in Love (1998)'),
#  (1.4226366, 'Dark Knight, The (2008)'),
#  (1.1691892, 'Big Lebowski, The (1998)'),
#  (0.92297173, 'Clueless (1995)'),
#  (1.306626, 'Rain Man (1988)'),
#  (1.4096192, 'Taxi Driver (1976)'),
#  (1.0029677, 'Fifth Element, The (1997)'),
#  (1.4891013, 'Casablanca (1942)'),
#  (1.3958631, 'Breakfast Club, The (1985)'),
#  (1.2629564, 'Wizard of Oz, The (1939)'),
#  (1.157016, 'Clear and Present Danger (1994)'),
#  (1.0533675, 'Minority Report (2002)'),
#  (0.72833037, 'Star Trek: Generations (1994)'),
#  (1.3506874, 'Beautiful Mind, A (2001)'),
#  (1.1927675, 'Crouching Tiger, Hidden Dragon (Wo hu cang long) (2000)'),
#  (0.33100313, 'Waterworld (1995)'),
#  (0.48442999, 'Armageddon (1998)'),
#  (1.6035373, 'Stand by Me (1986)'),
#  (0.69669032, 'Austin Powers: The Spy Who Shagged Me (1999)'),
#  (1.435912, 'Apocalypse Now (1979)'),
#  (0.7191503, 'American Pie (1999)'),
#  (0.97521287, 'Kill Bill: Vol. 1 (2003)'),
#  (1.3135179, 'Inception (2010)'),
#  (0.8805846, 'Firm, The (1993)'),
#  (0.86312175, 'Outbreak (1995)'),
#  (1.1578648, 'Clerks (1994)'),
#  (0.91610497, 'Who Framed Roger Rabbit? (1988)'),
#  (1.1091269, 'Jaws (1975)'),
#  (0.81528544, 'Jumanji (1995)'),
#  (1.1746081, 'Big (1988)'),
#  (1.3243133, 'American History X (1998)'),
#  (0.72699076, 'Austin Powers: International Man of Mystery (1997)'),
#  (0.77900463, 'Natural Born Killers (1994)'),
#  (1.1208826, 'Jerry Maguire (1996)'),
#  (1.3185675, 'Office Space (1999)'),
#  (1.1583086, 'Airplane! (1980)'),
#  (1.385103, 'Eternal Sunshine of the Spotless Mind (2004)'),
#  (0.50489044, 'Cliffhanger (1993)'),
#  (1.4930546,
#   'Dr. Strangelove or: How I Learned to Stop Worrying and Love the Bomb (1964)'),
#  (1.1826791, 'Batman Begins (2005)'),
#  (1.140299,
#   "Harry Potter and the Sorcerer's Stone (a.k.a. Harry Potter and the Philosopher's Stone) (2001)"),
#  (1.0348433, "Bug's Life, A (1998)"),
#  (1.3469921, 'Full Metal Jacket (1987)'),
#  (0.94183558, 'Total Recall (1990)'),
#  (1.2232625, 'Heat (1995)'),
#  (0.76120347, 'Beetlejuice (1988)'),
#  (1.2312191, 'Dead Man Walking (1995)'),
#  (1.3312628, 'Green Mile, The (1999)'),
#  (0.94815069, 'Kill Bill: Vol. 2 (2004)'),
#  (0.56751859, 'Net, The (1995)'),
#  (0.81949443, 'While You Were Sleeping (1995)'),
#  (1.3405339, 'Shining, The (1980)'),
#  (1.0318998, 'Leaving Las Vegas (1995)'),
#  (1.2451603, 'Bourne Identity, The (2002)'),
#  (1.5542179, 'Amadeus (1984)'),
#  (1.1981475, 'Almost Famous (2000)'),
#  (0.81967664, 'Chicken Run (2000)'),
#  (0.93663901, 'Back to the Future Part II (1989)'),
#  (1.4492172, 'Catch Me If You Can (2002)'),
#  (1.4089459, 'Life Is Beautiful (La Vita è bella) (1997)'),
#  (1.0626343, 'As Good as It Gets (1997)'),
#  (1.1682353, 'Indiana Jones and the Temple of Doom (1984)'),
#  (1.2301677, 'Hunt for Red October, The (1990)'),
#  (1.1589193, 'O Brother, Where Art Thou? (2000)'),
#  (0.82673156, 'Cast Away (2000)'),
#  (0.46792206, 'Demolition Man (1993)'),
#  (0.97010207, 'Get Shorty (1995)'),
#  (1.4383322, 'Snatch (2000)'),
#  (1.2399781, 'Dead Poets Society (1989)'),
#  (1.2453119, 'Blues Brothers, The (1980)'),
#  (0.75743639, 'Happy Gilmore (1996)'),
#  (0.75064284, 'Back to the Future Part III (1990)'),
#  (0.98955208, 'Birdcage, The (1996)'),
#  (1.2887309, 'Donnie Darko (2001)'),
#  (0.62636691, 'Broken Arrow (1996)'),
#  (1.601869, 'Rear Window (1954)'),
#  (1.0774117, 'Contact (1997)'),
#  (0.14450137, 'Ace Ventura: When Nature Calls (1995)'),
#  (1.24418, "Monty Python's Life of Brian (1979)"),
#  (1.0320876, 'Dave (1993)'),
#  (0.83941537, 'Grease (1978)'),
#  (0.93652189, 'Lethal Weapon (1987)'),
#  (1.0590992, 'Quiz Show (1994)'),
#  (1.0760864, 'Nightmare Before Christmas, The (1993)'),
#  (1.2484845, 'Edward Scissorhands (1990)'),
#  (1.4056587, 'Fish Called Wanda, A (1988)'),
#  (1.473649, 'Graduate, The (1967)'),
#  (0.93271381, 'Meet the Parents (2000)'),
#  (1.1456612, 'High Fidelity (2000)'),
#  (1.1967956, 'Casino (1995)'),
#  (1.1130083, "What's Eating Gilbert Grape (1993)"),
#  (1.1217144, "Mr. Holland's Opus (1995)"),
#  (1.5596601, 'North by Northwest (1959)'),
#  (1.2113922, 'When Harry Met Sally... (1989)'),
#  (1.1981078, 'Sense and Sensibility (1995)'),
#  (0.045788556, 'Blair Witch Project, The (1999)'),
#  (1.2257501, 'Philadelphia (1993)'),
#  (1.4699678, 'Citizen Kane (1941)'),
#  (1.0838693, 'Erin Brockovich (2000)'),
#  (1.1635109, 'Lost in Translation (2003)'),
#  (1.1332129, 'Harry Potter and the Prisoner of Azkaban (2004)'),
#  (1.101467, 'Gattaca (1997)'),
#  (1.5456426, 'Departed, The (2006)'),
#  (0.98875451, 'Spider-Man 2 (2004)'),
#  (0.86543459, 'Face/Off (1997)'),
#  (1.1894124, 'Star Trek: First Contact (1996)'),
#  (0.72785753, 'Matrix Reloaded, The (2003)'),
#  (1.233315, 'This Is Spinal Tap (1984)'),
#  (0.58973402, 'Star Wars: Episode II - Attack of the Clones (2002)'),
#  (1.1795779, 'American President, The (1995)'),
#  (0.89946359, 'X2: X-Men United (2003)'),
#  (0.97273815, 'Shrek 2 (2004)'),
#  (0.50854516, 'Mission: Impossible II (2000)'),
#  (1.1858858, 'Harry Potter and the Chamber of Secrets (2002)'),
#  (1.2968247, 'Sin City (2005)'),
#  (1.2330472, 'Crimson Tide (1995)'),
#  (1.5625657, 'To Kill a Mockingbird (1962)'),
#  (1.5390077, 'Run Lola Run (Lola rennt) (1998)'),
#  (0.49410674, 'Mars Attacks! (1996)'),
#  (1.2881417, 'Annie Hall (1977)'),
#  (1.1809022, 'In the Line of Fire (1993)'),
#  (1.3489201, 'Sound of Music, The (1965)'),
#  (1.2604377, 'Election (1999)'),
#  (0.72344816, 'Dogma (1999)'),
#  (0.25755003, "Charlie's Angels (2000)"),
#  (0.66937327, 'Mummy, The (1999)'),
#  (1.1719834, 'Piano, The (1993)'),
#  (1.0340974, 'Little Mermaid, The (1989)'),
#  (1.2260568, 'Untouchables, The (1987)'),
#  (1.2546804, 'Mary Poppins (1964)'),
#  (1.1488777, 'Ed Wood (1994)'),
#  (1.5164273, 'Psycho (1960)'),
#  (1.1840007, 'WALL·E (2008)'),
#  (1.0202806, 'Ransom (1996)'),
#  (0.92104578, 'My Cousin Vinny (1992)'),
#  (0.23241882, 'Honey, I Shrunk the Kids (1989)'),
#  (1.1468952, 'Few Good Men, A (1992)'),
#  (1.2166362, 'Game, The (1997)'),
#  (1.3413416, 'Little Miss Sunshine (2006)'),
#  (1.5253989, 'Chinatown (1974)'),
#  (1.409245, 'Wallace & Gromit: The Wrong Trousers (1993)'),
#  (1.4098127, 'Butch Cassidy and the Sundance Kid (1969)'),
#  (1.3537449, 'Iron Man (2008)'),
#  (0.73097479, 'Superman (1978)'),
#  (1.4059844, 'Christmas Story, A (1983)'),
#  (0.82570058, 'South Park: Bigger, Longer and Uncut (1999)'),
#  (0.8022902, 'Top Gun (1986)'),
#  (1.52807, 'Lock, Stock & Two Smoking Barrels (1998)'),
#  (0.87343532, "Wayne's World (1992)"),
#  (1.5023682, 'Young Frankenstein (1974)'),
#  (1.2311354, 'Bourne Supremacy, The (2004)'),
#  (1.6955771, '12 Angry Men (1957)'),
#  (1.1780635, 'English Patient, The (1996)'),
#  (0.74195462, 'Scream (1996)'),
#  (1.1014073, 'Traffic (2000)'),
#  (1.4006743, 'V for Vendetta (2006)'),
#  (0.63084829, 'Addams Family Values (1993)'),
#  (1.023366, 'Legends of the Fall (1994)'),
#  (0.68910289, 'Starship Troopers (1997)'),
#  (0.96101058, 'Star Trek II: The Wrath of Khan (1982)'),
#  (0.8514663, 'Phenomenon (1996)'),
#  (1.4958017, "It's a Wonderful Life (1946)"),
#  (1.2708486, 'Juno (2007)'),
#  (0.63305378, 'Liar Liar (1997)'),
#  (0.96826446, 'Maverick (1994)'),
#  (0.90116078, 'Abyss, The (1989)'),
#  (1.0302998, 'Snow White and the Seven Dwarfs (1937)'),
#  (0.82073945, "Bridget Jones's Diary (2001)"),
#  (0.52726001, 'Air Force One (1997)'),
#  (1.130895, 'Raising Arizona (1987)'),
#  (0.035000559, 'Judge Dredd (1995)'),
#  (0.33935425, 'Santa Clause, The (1994)'),
#  (0.78011751, 'Client, The (1994)'),
#  (1.2832505, 'Shaun of the Dead (2004)'),
#  (1.2191601, 'True Romance (1993)'),
#  (0.66008747, 'Wedding Singer, The (1998)'),
#  (1.0204241, 'Rocky (1976)'),
#  (1.1164353, 'Requiem for a Dream (2000)'),
#  (1.5411522, 'City of God (Cidade de Deus) (2002)'),
#  (1.4302746, 'Vertigo (1958)'),
#  (0.71952951, 'Eraser (1996)'),
#  (1.19863, 'Royal Tenenbaums, The (2001)'),
#  (1.3577279, 'Gone with the Wind (1939)'),
#  (1.177974, 'Rushmore (1998)'),
#  (0.49124449, 'Nutty Professor, The (1996)'),
#  (1.2609025, 'Platoon (1986)'),
#  (0.9334963, 'Field of Dreams (1989)'),
#  (1.0868268, 'Crow, The (1994)'),
#  (0.94282931, 'Enemy of the State (1998)'),
#  (0.32584751, 'Lost World: Jurassic Park, The (1997)'),
#  (0.92317486, 'Avatar (2009)'),
#  (0.50796896, 'Naked Gun 33 1/3: The Final Insult (1994)'),
#  (0.86679316, 'Talented Mr. Ripley, The (1999)'),
#  (0.76994056, 'Die Hard 2 (1990)'),
#  (1.1434613, 'Sling Blade (1996)'),
#  (1.1908321, 'Some Like It Hot (1959)'),
#  (0.9817782, 'Pinocchio (1940)'),
#  (0.60182804, 'Robin Hood: Men in Tights (1993)'),
#  (0.81481749, 'Star Trek IV: The Voyage Home (1986)'),
#  (1.0286288, 'Romancing the Stone (1984)'),
#  (0.86490172, 'Galaxy Quest (1999)'),
#  (0.64204729, 'Patriot, The (2000)'),
#  (0.91175812, 'Chasing Amy (1997)'),
#  (1.4105266, 'Bridge on the River Kwai, The (1957)'),
#  (1.1077327, 'Million Dollar Baby (2004)'),
#  (1.1836636, 'Grosse Pointe Blank (1997)'),
#  (0.63035387, 'Batman Returns (1992)'),
#  (1.052592, 'Exorcist, The (1973)'),
#  (1.0054353, 'Pleasantville (1998)'),
#  (1.5447894, "Singin' in the Rain (1952)"),
#  (1.1401527, 'Fantasia (1940)'),
#  (1.2050209, 'Full Monty, The (1997)'),
#  (0.83112246, 'Notting Hill (1999)'),
#  (0.13621312, "City Slickers II: The Legend of Curly's Gold (1994)"),
#  (1.4588293, 'Spirited Away (Sen to Chihiro no kamikakushi) (2001)'),
#  (0.88006473, 'Desperado (1995)'),
#  (1.0757182, 'Eyes Wide Shut (1999)'),
#  (0.60537422, 'Rocky Horror Picture Show, The (1975)'),
#  (0.84656131, 'Ice Age (2002)'),
#  (-0.10592183, 'Congo (1995)'),
#  (1.1795954, 'Sting, The (1973)'),
#  (1.2850108, 'Close Encounters of the Third Kind (1977)'),
#  (1.3484317, 'Brazil (1985)'),
#  (1.5266804, 'Wallace & Gromit: A Close Shave (1995)'),
#  (0.51236969, 'Dragonheart (1996)'),
#  (1.5742588, 'Maltese Falcon, The (1941)'),
#  (0.95148462, 'Star Wars: Episode III - Revenge of the Sith (2005)'),
#  (1.3210226, 'Blazing Saddles (1974)'),
#  (1.2962394, 'Like Water for Chocolate (Como agua para chocolate) (1992)'),
#  (1.3581865, 'Boogie Nights (1997)'),
#  (0.5027675, 'Arachnophobia (1990)'),
#  (0.57833767, 'Unbreakable (2000)'),
#  (1.2847872, 'Casino Royale (2006)'),
#  (0.2726751, 'Pocahontas (1995)'),
#  (1.3454187, 'Hoop Dreams (1994)'),
#  (0.83046758, 'Truth About Cats & Dogs, The (1996)'),
#  (0.85086602, 'Executive Decision (1996)'),
#  (1.6473137, 'Pianist, The (2002)'),
#  (1.2926384, 'Up (2009)'),
#  (1.0736244, 'Heathers (1989)'),
#  (1.2909842, 'Bourne Ultimatum, The (2007)'),
#  (0.5719223, "You've Got Mail (1998)"),
#  (0.75560713, 'Crocodile Dundee (1986)'),
#  (0.82506174, 'Kingpin (1996)'),
#  (0.6621632, 'French Kiss (1995)'),
#  (0.92110819, "The Devil's Advocate (1997)"),
#  (1.4129014, 'Much Ado About Nothing (1993)'),
#  (1.0744323, 'Best in Show (2000)'),
#  (1.3514379, 'Harry Potter and the Goblet of Fire (2005)'),
#  (0.70071101, 'Con Air (1997)'),
#  (0.83961791, 'Wag the Dog (1997)'),
#  (1.2601469, 'Ratatouille (2007)'),
#  (1.0322468, "Pirates of the Caribbean: Dead Man's Chest (2006)"),
#  (0.54623568, 'Grumpier Old Men (1995)'),
#  (1.5022523, 'Inglourious Basterds (2009)'),
#  (0.055878602, 'Cable Guy, The (1996)'),
#  (0.91314691, '300 (2007)'),
#  (0.96780926, 'M*A*S*H (a.k.a. MASH) (1970)'),
#  (1.1831523, 'Animal House (1978)'),
#  (0.66231579, 'Hot Shots! Part Deux (1993)'),
#  (0.26671419, 'Casper (1995)'),
#  (1.2669475, 'Bowling for Columbine (2002)'),
#  (0.83215433, 'RoboCop (1987)'),
#  (0.73279655, 'Blade (1998)'),
#  (1.0933846, 'Glory (1989)'),
#  (0.9584446, 'Spaceballs (1987)'),
#  (0.97897238, 'Garden State (2004)'),
#  (0.80189323, "William Shakespeare's Romeo + Juliet (1996)"),
#  (1.0032209, 'Unforgiven (1992)'),
#  (0.87679774, 'Magnolia (1999)'),
#  (0.567505, 'Lethal Weapon 2 (1989)'),
#  (1.0567694, 'Jackie Brown (1997)'),
#  (0.83717769, 'Tombstone (1993)'),
#  (1.0160279, 'Planet of the Apes (1968)'),
#  (1.0563335, '10 Things I Hate About You (1999)'),
#  (0.17651425, 'Beverly Hills Cop III (1994)'),
#  (1.3231343,
#   'Good, the Bad and the Ugly, The (Buono, il brutto, il cattivo, Il) (1966)'),
#  (0.76927298, 'I, Robot (2004)'),
#  (0.83058035, 'League of Their Own, A (1992)'),
#  (0.31683162, 'Gone in 60 Seconds (2000)'),
#  (0.7477358, 'Basic Instinct (1992)'),
#  (1.2222604, 'Bonnie and Clyde (1967)'),
#  (0.85406631, "Muriel's Wedding (1994)"),
#  (0.62483191, 'Father of the Bride Part II (1995)'),
#  (1.3844076, 'Witness (1985)'),
#  (0.91028178, 'Italian Job, The (2003)'),
#  (0.75282502, 'Mask of Zorro, The (1998)'),
#  (0.89664954, 'Cinderella (1950)'),
#  (1.2028805, 'Big Fish (2003)'),
#  (0.58602941, 'Alien³ (a.k.a. Alien 3) (1992)'),
#  (1.065487, 'Love Actually (2003)'),
#  (0.99748391, 'Moulin Rouge (2001)'),
#  (0.41971245, 'Species (1995)'),
#  (0.52030277, 'A.I. Artificial Intelligence (2001)'),
#  (-0.13664536, 'Coneheads (1993)'),
#  (1.6291504, 'Seven Samurai (Shichinin no samurai) (1954)'),
#  (0.52991015, 'Matrix Revolutions, The (2003)'),
#  (1.1429108, 'Manhattan (1979)'),
#  (1.0334592, 'Caddyshack (1980)'),
#  (0.76575845, 'Star Trek III: The Search for Spock (1984)'),
#  (0.81707937, 'Signs (2002)'),
#  (0.81204909, 'Dirty Dancing (1987)'),
#  (1.2635427, 'District 9 (2009)'),
#  (0.40420446, 'Perfect Storm, The (2000)'),
#  (0.66911787, 'Sabrina (1995)'),
#  (1.0654356, 'James and the Giant Peach (1996)'),
#  (0.40580812, 'Last Action Hero (1993)'),
#  (0.81939548, 'Predator (1987)'),
#  (1.0930805, 'Goldfinger (1964)'),
#  (0.36301726, 'Miss Congeniality (2000)'),
#  (1.07725, 'Good Morning, Vietnam (1987)'),
#  (0.68936974, 'Antz (1998)'),
#  (1.1273532, 'Slumdog Millionaire (2008)'),
#  (1.019035, "Pan's Labyrinth (Laberinto del fauno, El) (2006)"),
#  (0.92715067, 'So I Married an Axe Murderer (1993)'),
#  (1.4387654, 'Prestige, The (2006)'),
#  (1.0543834, 'About a Boy (2002)'),
#  (1.1679006, 'Army of Darkness (1993)'),
#  (1.1949774, '28 Days Later (2002)'),
#  (0.92415363, 'Fast Times at Ridgemont High (1982)'),
#  (1.1324193, 'Sleepy Hollow (1999)'),
#  (0.6869452, 'Tin Cup (1996)'),
#  (0.66438466, "My Best Friend's Wedding (1997)"),
#  (0.55825573, 'Splash (1984)'),
#  (0.98458171, "Dracula (Bram Stoker's Dracula) (1992)"),
#  (0.63390803, 'Disclosure (1994)'),
#  (0.61437786, 'Analyze This (1999)'),
#  (0.93932176, 'School of Rock (2003)'),
#  (0.90587217, 'Dark City (1998)'),
#  (0.82908553, 'My Big Fat Greek Wedding (2002)'),
#  (0.65806627, 'American Psycho (2000)'),
#  (1.2223766, 'Chicago (2002)'),
#  (1.2524463, 'Shutter Island (2010)'),
#  (0.86854422, 'Mighty Aphrodite (1995)'),
#  (0.58156109, 'Bowfinger (1999)'),
#  (1.1347276, 'Little Women (1994)'),
#  (0.95811677, 'Lady and the Tramp (1955)'),
#  (1.0191165, 'Star Trek (2009)'),
#  (0.87326652, 'Goonies, The (1985)'),
#  (1.4927183, 'Boot, Das (Boat, The) (1981)'),
#  (0.91202486, 'Sneakers (1992)'),
#  (1.148862, 'My Fair Lady (1964)'),
#  (1.1676013, 'Birds, The (1963)'),
#  (0.96857363, 'Jerk, The (1979)'),
#  (0.70337349, 'Cruel Intentions (1999)'),
#  (1.5205759, 'Lawrence of Arabia (1962)'),
#  (1.1510293, 'Beverly Hills Cop (1984)'),
#  (1.0626554, '40-Year-Old Virgin, The (2005)'),
#  (0.58590204, 'Bruce Almighty (2003)'),
#  (1.638744, 'Raging Bull (1980)'),
#  (1.233532, 'Go (1999)'),
#  (0.5915066, 'Three Musketeers, The (1993)'),
#  (1.1359758, 'Crying Game, The (1992)'),
#  (0.17820698, 'Space Jam (1996)'),
#  (1.1362798, 'Primal Fear (1996)'),
#  (1.7238756, 'African Queen, The (1951)'),
#  (0.80401534, 'Tommy Boy (1995)'),
#  (0.94709384, 'Fatal Attraction (1987)'),
#  (0.80840355, 'That Thing You Do! (1996)'),
#  (0.64699721, 'Tomorrow Never Dies (1997)'),
#  (1.0570489, 'Scarface (1983)'),
#  (0.68451732, 'Hunchback of Notre Dame, The (1996)'),
#  (0.95729941,
#   'Chronicles of Narnia: The Lion, the Witch and the Wardrobe, The (2005)'),
#  (0.61220509, 'Men in Black II (a.k.a. MIIB) (a.k.a. MIB 2) (2002)'),
#  (1.1640078, 'Time to Kill, A (1996)'),
#  (1.1295265, 'Black Hawk Down (2001)'),
#  (1.1433104, 'Hudsucker Proxy, The (1994)'),
#  (0.77979863, 'Alice in Wonderland (1951)'),
#  (1.318931, 'Great Escape, The (1963)'),
#  (0.9300307, 'Highlander (1986)'),
#  (0.63137031, 'Mr. & Mrs. Smith (2005)'),
#  (1.0423131, 'Others, The (2001)'),
#  (1.3508515, 'Manchurian Candidate, The (1962)'),
#  (0.8008489, 'Rumble in the Bronx (Hont faan kui) (1995)'),
#  (1.2347895, 'No Country for Old Men (2007)'),
#  (0.93377012, 'Adventures of Priscilla, Queen of the Desert, The (1994)'),
#  (1.1189882, 'Deer Hunter, The (1978)'),
#  (0.4920364, 'Deep Impact (1998)'),
#  (1.1176847, 'Patriot Games (1992)'),
#  (1.1020654, 'Elizabeth (1998)'),
#  (0.84997123, 'Escape from New York (1981)'),
#  (0.20075971, 'Johnny Mnemonic (1995)'),
#  (0.56550688, 'From Dusk Till Dawn (1996)'),
#  (0.99644637, 'Rob Roy (1995)'),
#  (0.94814098, 'Trading Places (1983)'),
#  (0.72406143, 'The Butterfly Effect (2004)'),
#  (0.56704485, 'Bridges of Madison County, The (1995)'),
#  (1.0489711, 'Dark Knight Rises, The (2012)'),
#  (0.36815608, 'Nine Months (1995)'),
#  (1.3773284, 'Crash (2004)'),
#  (0.89593512, 'Ring, The (2002)'),
#  (0.61441821, 'Charlie and the Chocolate Factory (2005)'),
#  (0.5991137, 'Star Trek VI: The Undiscovered Country (1991)'),
#  (0.70054853, 'River Wild, The (1994)'),
#  (0.87444365, 'Tron (1982)'),
#  (0.70563155, 'Legally Blonde (2001)'),
#  (0.57147676, 'Gremlins (1984)'),
#  (-0.53874791, 'Wild Wild West (1999)'),
#  (1.1596122, 'Say Anything... (1989)'),
#  (0.5704208, 'Fly, The (1986)'),
#  (-0.26020217, 'Batman & Robin (1997)'),
#  (0.6520704, 'X-Files: Fight the Future, The (1998)'),
#  (0.60142076, 'Star Trek: The Motion Picture (1979)'),
#  (0.39902076, 'Beavis and Butt-Head Do America (1996)'),
#  (0.68268824, 'Zoolander (2001)'),
#  (1.4081221, 'French Connection, The (1971)'),
#  (0.86343789, 'Fahrenheit 9/11 (2004)'),
#  (1.1123626, 'Three Kings (1999)'),
#  (1.3069371, 'Ben-Hur (1959)'),
#  (1.2849224, 'Sixteen Candles (1984)'),
#  (1.7815869, 'Cinema Paradiso (Nuovo cinema Paradiso) (1989)'),
#  (1.5421882, 'Cool Hand Luke (1967)'),
#  (0.9881466, 'Jungle Book, The (1967)'),
#  (1.0656564, 'Avengers, The (2012)'),
#  (1.1641819, 'Mystic River (2003)'),
#  (1.303404, 'Remains of the Day, The (1993)'),
#  (1.3981737, 'Gandhi (1982)'),
#  (1.2922382, 'Searching for Bobby Fischer (1993)'),
#  (0.58381164, "Romy and Michele's High School Reunion (1997)"),
#  (1.3414224, 'Wallace & Gromit: The Best of Aardman Animation (1996)'),
#  (0.815534, 'Sideways (2004)'),
#  (0.3658554, 'Alien: Resurrection (1997)'),
#  (0.24388799, 'Austin Powers in Goldmember (2002)'),
#  (1.2021716, 'Insider, The (1999)'),
#  (0.80664462, 'Thelma & Louise (1991)'),
#  (0.19121183, 'Runaway Bride (1999)'),
#  (1.1274681, 'Last Samurai, The (2003)'),
#  (1.2078717, '(500) Days of Summer (2009)'),
#  (1.3158599, 'West Side Story (1961)'),
#  (1.1838419, 'Misery (1990)'),
#  (1.2040852, 'Postman, The (Postino, Il) (1994)'),
#  (1.1775265, 'Chocolat (2000)'),
#  (0.92197448, 'Little Shop of Horrors (1986)'),
#  (0.71627498, 'Napoleon Dynamite (2004)'),
#  (0.88828397, 'Super Size Me (2004)'),
#  (1.3039434, 'Right Stuff, The (1983)'),
#  (0.62798333, 'What Women Want (2000)'),
#  (0.80132687, 'Nell (1994)'),
#  (1.0027355, 'Hangover, The (2009)'),
#  (0.8904258, "Breakfast at Tiffany's (1961)"),
#  (0.50105655, 'Robin Hood: Prince of Thieves (1991)'),
#  (0.62501568,
#   'Borat: Cultural Learnings of America for Make Benefit Glorious Nation of Kazakhstan (2006)'),
#  (1.2514226, 'Django Unchained (2012)'),
#  (1.3172181, 'Player, The (1992)'),
#  (1.1368048, 'Bull Durham (1988)'),
#  (0.24994518, 'Specialist, The (1994)'),
#  (1.1136978, 'Fear and Loathing in Las Vegas (1998)'),
#  (0.27433845, 'Planet of the Apes (2001)'),
#  (0.8529982, 'Conspiracy Theory (1997)'),
#  (1.2495568, 'Superbad (2007)'),
#  (1.1748562, "Boys Don't Cry (1999)"),
#  (1.10225, 'Harold and Maude (1971)'),
#  (0.81784052, 'Mallrats (1995)'),
#  (0.6368438, 'Hook (1991)'),
#  (0.21602862, 'Me, Myself & Irene (2000)'),
#  (0.89659131, 'Strange Days (1995)'),
#  (1.0785552, 'Billy Elliot (2000)'),
#  (0.73981082, 'Bad Boys (1995)'),
#  (0.662211, 'Cocoon (1985)'),
#  (0.64476442, 'Double Jeopardy (1999)'),
#  (1.2747022, 'Social Network, The (2010)'),
#  (0.97393352, 'Last of the Mohicans, The (1992)'),
#  (0.51903772, 'First Knight (1995)'),
#  (1.0026531, 'To Die For (1995)'),
#  (0.98402423, 'Children of Men (2006)'),
#  (0.34766087, 'Ghostbusters II (1989)'),
#  (0.8952629, 'Rush Hour (1998)'),
#  (0.98592925, 'Heavenly Creatures (1994)'),
#  (0.67640483, 'Time Bandits (1981)'),
#  (1.3897835, 'Interstellar (2014)'),
#  (1.3711791, 'Toy Story 3 (2010)'),
#  (1.2004806, 'JFK (1991)'),
#  (1.5203456, 'Swingers (1996)'),
#  (1.0194592, 'Adaptation (2002)'),
#  (0.89404708, 'Risky Business (1983)'),
#  (0.46112952, 'Billy Madison (1995)'),
#  (0.42925665, 'Pearl Harbor (2001)'),
#  (0.96490473, 'Pretty in Pink (1986)'),
#  (0.56306767, 'Dangerous Minds (1995)'),
#  (1.2407538, 'Chariots of Fire (1981)'),
#  (0.63886768, 'Lethal Weapon 4 (1998)'),
#  (0.71858364, 'I Am Legend (2007)'),
#  (1.0069691, 'Dumbo (1941)'),
#  (0.48174822, 'Willow (1988)'),
#  (1.0364443, 'Wedding Crashers (2005)'),
#  (0.11609176, 'Junior (1994)'),
#  (1.2738838, 'Walk the Line (2005)'),
#  (1.1018422, 'Iron Giant, The (1999)'),
#  (0.85318887, 'Aristocats, The (1970)'),
#  (0.98662132, 'Mulan (1998)'),
#  (1.6874273, 'Roger & Me (1989)'),
#  (1.1253004, 'Hot Fuzz (2007)'),
#  (0.61859816, '101 Dalmatians (One Hundred and One Dalmatians) (1961)'),
#  (0.59595025, 'Entrapment (1999)'),
#  (0.45313981, 'I.Q. (1994)'),
#  (1.2125908, 'Frequency (2000)'),
#  (0.438896, 'Brady Bunch Movie, The (1995)'),
#  (1.3253083, 'Emma (1996)'),
#  (1.1881112, 'Blue Velvet (1986)'),
#  (0.88879925, 'Bend It Like Beckham (2002)'),
#  (0.71071649, 'Fast and the Furious, The (2001)'),
#  (1.2044843, "King's Speech, The (2010)"),
#  (1.1684783, 'Sherlock Holmes (2009)'),
#  (1.1102424, "Bill & Ted's Excellent Adventure (1989)"),
#  (1.3021764, 'Rebel Without a Cause (1955)'),
#  (1.3637589,
#   'City of Lost Children, The (Cité des enfants perdus, La) (1995)'),
#  (1.3094935, 'Bullets Over Broadway (1994)'),
#  (1.1683542, 'Streetcar Named Desire, A (1951)'),
#  (1.0042828, 'Grifters, The (1990)'),
#  (1.073903, 'Stripes (1981)'),
#  (1.4145597, 'Patton (1970)'),
#  (1.0645254, 'Fried Green Tomatoes (1991)'),
#  (1.059293, 'Driving Miss Daisy (1989)'),
#  (1.3041769, 'Ronin (1998)'),
#  (1.1917013, 'Pi (1998)'),
#  (1.3734998, 'Thank You for Smoking (2006)'),
#  (1.2805209, 'Serenity (2005)'),
#  (1.219308, 'Collateral (2004)'),
#  (0.44279441, 'War of the Worlds (2005)'),
#  (1.0014912, 'Stranger than Fiction (2006)'),
#  (1.2870289, 'Femme Nikita, La (Nikita) (1990)'),
#  (0.4179633, 'American Pie 2 (2001)'),
#  (1.1878675, 'Remember the Titans (2000)'),
#  (-0.04405624, 'Striptease (1996)'),
#  (1.5361043, 'Sunset Blvd. (a.k.a. Sunset Boulevard) (1950)'),
#  (0.52045977, 'Lethal Weapon 3 (1992)'),
#  (0.86341053, 'Thomas Crown Affair, The (1999)'),
#  (1.5961121, 'Grand Day Out with Wallace and Gromit, A (1989)'),
#  (1.243385, 'Sleeper (1973)'),
#  (0.68560511, 'Wild Things (1998)'),
#  (1.0111002, 'L.A. Story (1991)'),
#  (1.2877071, 'Midnight Cowboy (1969)'),
#  (1.225868, 'Donnie Brasco (1997)'),
#  (0.98735911, 'Cape Fear (1991)'),
#  (-0.19922346, 'Flintstones, The (1994)'),
#  (1.2976547, 'Madness of King George, The (1994)'),
#  (1.0299911, 'Mulholland Drive (2001)'),
#  (0.84647542, 'Cider House Rules, The (1999)'),
#  (0.66253906, 'The Hunger Games (2012)'),
#  (0.89481348, 'Road to Perdition (2002)'),
#  (1.1927018, 'Network (1976)'),
#  (1.1178095, 'Shallow Grave (1994)'),
#  (0.9680776, 'American Werewolf in London, An (1981)'),
#  (0.55410886, 'Superman II (1980)'),
#  (0.74966669, 'Karate Kid, The (1984)'),
#  (0.87355167, 'Peter Pan (1953)'),
#  (1.4424701, 'Princess Mononoke (Mononoke-hime) (1997)'),
#  (1.0712889, 'Poltergeist (1982)'),
#  (1.7917278, 'Third Man, The (1949)'),
#  (1.4413817, 'American Graffiti (1973)'),
#  (0.51140726, 'Terminator 3: Rise of the Machines (2003)'),
#  (1.784539, 'All About Eve (1950)'),
#  (0.75475788, 'NeverEnding Story, The (1984)'),
#  (0.83825278, 'Shanghai Noon (2000)'),
#  (1.1199862, 'Harry Potter and the Order of the Phoenix (2007)'),
#  (0.57075208, 'Copycat (1995)'),
#  (0.39203241, 'Mortal Kombat (1995)'),
#  (1.3928006, 'In Bruges (2008)'),
#  (1.1161687, 'Lives of Others, The (Das leben der Anderen) (2006)'),
#  (0.5815165, 'Sister Act (1992)'),
#  (1.1828421, 'Dazed and Confused (1993)'),
#  (0.59375709, 'Road Trip (2000)'),
#  (1.2799605, 'Finding Neverland (2004)'),
#  (0.85141611, 'Fisher King, The (1991)'),
#  (1.608779, 'Philadelphia Story, The (1940)'),
#  (1.4849181, 'Blood Diamond (2006)'),
#  (0.78144711, 'Dodgeball: A True Underdog Story (2004)'),
#  (0.96138537, '20,000 Leagues Under the Sea (1954)'),
#  (0.53605044, '101 Dalmatians (1996)'),
#  (1.4099767, "Monty Python's The Meaning of Life (1983)"),
#  (0.71802628, 'Training Day (2001)'),
#  (1.0088747, 'Arsenic and Old Lace (1944)'),
#  (0.98741168, 'Zombieland (2009)'),
#  (1.0295416, 'Carrie (1976)'),
#  (1.4623942, 'Shine (1996)'),
#  (0.073453546, 'Scary Movie (2000)'),
#  (1.1900278, 'Moonstruck (1987)'),
#  (0.97583365, 'Blow (2001)'),
#  (1.1071042, 'Enemy at the Gates (2001)'),
#  (0.89791167, 'Simpsons Movie, The (2007)'),
#  (1.0836457, 'Guardians of the Galaxy (2014)'),
#  (0.4212164, 'Vanilla Sky (2001)'),
#  (0.87991798, 'Terminal, The (2004)'),
#  (0.78752512, 'Weird Science (1985)'),
#  (1.2079691, 'Broadcast News (1987)'),
#  (1.1492534, "Rosemary's Baby (1968)"),
#  (0.99327099, 'Arlington Road (1999)'),
#  (1.1498817, 'Big Chill, The (1983)'),
#  (0.60940081, 'Craft, The (1996)'),
#  (1.4155483, 'Rounders (1998)'),
#  (0.59974468, 'Mystery Men (1999)'),
#  (1.2341018, 'Rudy (1993)'),
#  (1.1805056, 'Gods Must Be Crazy, The (1980)'),
#  (1.0515683, 'Labyrinth (1986)'),
#  (1.090921, 'Ghost World (2001)'),
#  (0.64252663, 'World Is Not Enough, The (1999)'),
#  (0.79576397, 'Doors, The (1991)'),
#  (0.7808972, 'Planes, Trains & Automobiles (1987)'),
#  (1.2253242, 'Gran Torino (2008)'),
#  (0.76403356, 'Thin Red Line, The (1998)'),
#  (1.0800594, 'Muppet Movie, The (1979)'),
#  (0.83073127, 'Prince of Egypt, The (1998)'),
#  (1.3578305, 'Lone Star (1996)'),
#  (0.5295189, 'Lara Croft: Tomb Raider (2001)'),
#  (0.64574409, 'Da Vinci Code, The (2006)'),
#  (1.4037626, 'Wonder Boys (2000)'),
#  (0.7772969, 'Addams Family, The (1991)'),
#  (0.93688971, 'Don Juan DeMarco (1995)'),
#  (1.5556878, 'Killing Fields, The (1984)'),
#  (1.5453302, 'October Sky (1999)'),
#  (1.0739322, 'Natural, The (1984)'),
#  (0.97219497, 'Godfather: Part III, The (1990)'),
#  (0.3945305, 'Desperately Seeking Susan (1985)'),
#  (0.69554156, 'Saint, The (1997)'),
#  (1.2117602, 'Naked Gun: From the Files of Police Squad!, The (1988)'),
#  (1.1192214, 'Mad Max (1979)'),
#  (1.1362269, 'Equilibrium (2002)'),
#  (0.78933662, 'National Treasure (2004)'),
#  (-0.4835321, 'Showgirls (1995)'),
#  (0.86448497, 'Man on the Moon (1999)'),
#  (0.65544683, 'Miracle on 34th Street (1994)'),
#  (0.56725544, 'Never Been Kissed (1999)'),
#  (1.0175483, 'Sleeping Beauty (1959)'),
#  (1.0299897, 'Dirty Dozen, The (1967)'),
#  (1.3180649, 'Grand Budapest Hotel, The (2014)'),
#  (1.0241165, 'Gangs of New York (2002)'),
#  (1.5696292, 'Harry Potter and the Deathly Hallows: Part 2 (2011)'),
#  (0.87721646, 'Strictly Ballroom (1992)'),
#  (0.83949941, 'Master and Commander: The Far Side of the World (2003)'),
#  (0.82082927, "Hitchhiker's Guide to the Galaxy, The (2005)"),
#  (0.57973367, 'Reality Bites (1994)'),
#  (1.0284662, 'Anchorman: The Legend of Ron Burgundy (2004)'),
#  (1.1512533, 'Terms of Endearment (1983)'),
#  (1.1528407, 'Dangerous Liaisons (1988)'),
#  (0.75346595, 'Bambi (1942)'),
#  (0.454308, "Ocean's Twelve (2004)"),
#  (0.26078779, 'Deep Blue Sea (1999)'),
#  (1.1589478, 'Aviator, The (2004)'),
#  (0.83540785, 'About Schmidt (2002)'),
#  (1.1259971, 'Akira (1988)'),
#  (1.0756773, 'Black Swan (2010)'),
#  (0.24544735, 'Multiplicity (1996)'),
#  (0.59426767, 'Powder (1995)'),
#  (1.3376749, 'Duck Soup (1933)'),
#  (0.43820149, 'Cell, The (2000)'),
#  (0.70457447, 'Forget Paris (1995)'),
#  (1.0938714, 'Harry Potter and the Deathly Hallows: Part 1 (2010)'),
#  (1.0468491, 'WarGames (1983)'),
#  (1.1312444, 'Thing, The (1982)'),
#  (0.4001258, 'Michael (1996)'),
#  (1.1373173, 'Evil Dead II (Dead by Dawn) (1987)'),
#  (1.1855893, 'Illusionist, The (2006)'),
#  (1.4531567, 'Producers, The (1968)'),
#  (1.3527411, 'How to Train Your Dragon (2010)'),
#  (0.95160663, 'Saw (2004)'),
#  (0.7328757,
#   'Englishman Who Went Up a Hill But Came Down a Mountain, The (1995)'),
#  (0.77912766, 'Notebook, The (2004)'),
#  (0.8397842, 'Heavy Metal (1981)'),
#  (1.259106, 'Mystery Science Theater 3000: The Movie (1996)'),
#  (0.93420315, 'Sleepers (1996)'),
#  (1.1649293, 'People vs. Larry Flynt, The (1996)'),
#  (1.2714087, 'Hero (Ying xiong) (2002)'),
#  (1.0067786, 'Negotiator, The (1998)'),
#  (1.39368, 'Crumb (1994)'),
#  (0.35526371, 'Swordfish (2001)'),
#  (0.5997715, 'Hannibal (2001)'),
#  (1.2948686, 'Kung Fu Panda (2008)'),
#  (0.77143067, "Pirates of the Caribbean: At World's End (2007)"),
#  (1.2598388, 'Apartment, The (1960)'),
#  (1.3082498, 'Big Sleep, The (1946)'),
#  (1.5388861, 'Three Colors: Red (Trois couleurs: Rouge) (1994)'),
#  (0.19804706, 'Mummy Returns, The (2001)'),
#  (0.75056553, 'Kalifornia (1993)'),
#  (1.1711957, "Carlito's Way (1993)"),
#  (1.5808278, 'The Imitation Game (2014)'),
#  (0.66235131, 'Troy (2004)'),
#  (1.2856765, 'Hotel Rwanda (2004)'),
#  (0.51892519, 'Scream 2 (1997)'),
#  (1.1153156, "Emperor's New Groove, The (2000)"),
#  (1.0831844, 'From Russia with Love (1963)'),
#  (0.34250781, 'Indian in the Cupboard, The (1995)'),
#  (1.0828223, 'Payback (1999)'),
#  (1.0231797, 'Do the Right Thing (1989)'),
#  (0.72343862, 'Rocketeer, The (1991)'),
#  (0.60829782, 'Nightmare on Elm Street, A (1984)'),
#  (1.4119403, 'Double Indemnity (1944)'),
#  (1.3461438, 'Deliverance (1972)'),
#  (1.1972786, 'Repo Man (1984)'),
#  (0.83139592, 'Old School (2003)'),
#  (0.71441418, 'Hercules (1997)'),
#  (0.8982482, 'Backdraft (1991)'),
#  (1.8369386, 'Modern Times (1936)'),
#  (1.0862066, 'Old Boy (2003)'),
#  (0.60650635, 'Bulworth (1998)'),
#  (1.4174416, 'Last Emperor, The (1987)'),
#  (1.3175238, 'Mad Max: Fury Road (2015)'),
#  (1.195146, 'Color Purple, The (1985)'),
#  (1.15943, 'Lord of War (2005)'),
#  (0.98653501, 'Dr. No (1962)'),
#  (0.77532721, 'Grumpy Old Men (1993)'),
#  (1.0889381, 'Falling Down (1993)'),
#  (1.1609578, 'Into the Wild (2007)'),
#  (0.9637081, 'Nixon (1995)'),
#  (0.8101297, 'Bob Roberts (1992)'),
#  (0.90947151, 'Room with a View, A (1986)'),
#  (0.61936814, 'Transformers (2007)'),
#  (0.15033597, 'Free Willy (1993)'),
#  (0.0991631, 'Home Alone 2: Lost in New York (1992)'),
#  (1.0130857, 'Ordinary People (1980)'),
#  (1.2749257, 'Kramer vs. Kramer (1979)'),
#  (0.12325453, 'Jurassic Park III (2001)'),
#  (1.0992944, 'Taken (2008)'),
#  (1.5412779, 'In the Name of the Father (1993)'),
#  (1.6041476, 'Three Colors: Blue (Trois couleurs: Bleu) (1993)'),
#  (0.95405895, 'Jewel of the Nile, The (1985)'),
#  (0.62915957, "General's Daughter, The (1999)"),
#  (0.98627555, 'Courage Under Fire (1996)'),
#  (0.9701429, 'Simple Plan, A (1998)'),
#  (0.9169277, '¡Three Amigos! (1986)'),
#  (0.45323431, 'Under Siege 2: Dark Territory (1995)'),
#  (0.90585876, 'Secret Garden, The (1993)'),
#  (0.35845447, 'Die Another Day (2002)'),
#  (0.69685501, 'Jay and Silent Bob Strike Back (2001)'),
#  (1.3751707, 'Grapes of Wrath, The (1940)'),
#  (1.6930161, 'Mr. Smith Goes to Washington (1939)'),
#  (0.30032313, 'Babe: Pig in the City (1998)'),
#  (0.81270373, 'Scrooged (1988)'),
#  (1.4936209, 'Delicatessen (1991)'),
#  (0.92061418, 'Virgin Suicides, The (1999)'),
#  (1.2197496, 'Burn After Reading (2008)'),
#  (1.1825057, 'Curious Case of Benjamin Button, The (2008)'),
#  (1.6323329, "Amores Perros (Love's a Bitch) (2000)"),
#  (0.4849034, 'Flashdance (1983)'),
#  (1.1555827, 'Kick-Ass (2010)'),
#  (1.0759286, 'Bringing Up Baby (1938)'),
#  (-0.37551808, 'Hollow Man (2000)'),
#  (0.70752054, '21 Grams (2003)'),
#  (1.8028125, 'Waking Ned Devine (a.k.a. Waking Ned) (1998)'),
#  (0.63437265, 'Mexican, The (2001)'),
#  (1.1130314, 'Out of Africa (1985)'),
#  (1.3170903, "Hard Day's Night, A (1964)"),
#  (1.3969629, 'Scent of a Woman (1992)'),
#  (0.67123705, 'Long Kiss Goodnight, The (1996)'),
#  (0.14255084, 'Mission to Mars (2000)'),
#  (0.5264886, 'Dune (1984)'),
#  (1.0431263, 'Welcome to the Dollhouse (1995)'),
#  (-0.039945483, 'I Know What You Did Last Summer (1997)'),
#  (0.60334527, 'Bone Collector, The (1999)'),
#  (0.88149571, 'Jungle Book, The (1994)'),
#  (1.6334213, 'Treasure of the Sierra Madre, The (1948)'),
#  (1.0294363, "National Lampoon's Vacation (1983)"),
#  (0.78732395, 'Panic Room (2002)'),
#  (0.48154435, 'When a Man Loves a Woman (1994)'),
#  (1.3080136, 'Midnight Run (1988)'),
#  (0.93804336, 'Cool Runnings (1993)'),
#  (0.90515757, '50 First Dates (2004)'),
#  (1.4087931, 'To Catch a Thief (1955)'),
#  (0.82402515, 'Iron Man 2 (2010)'),
#  (1.4284836, 'Harry Potter and the Half-Blood Prince (2009)'),
#  (1.1322868, 'Kiss Kiss Bang Bang (2005)'),
#  (0.44363186, 'How the Grinch Stole Christmas (a.k.a. The Grinch) (2000)'),
#  (0.70164138, 'Brokeback Mountain (2005)'),
#  (1.3450856, 'Wolf of Wall Street, The (2013)'),
#  (1.2500582, 'Tootsie (1982)'),
#  (1.1245872, 'Gravity (2013)'),
#  (0.60309631, "She's All That (1999)"),
#  (1.2764298, 'Waiting for Guffman (1996)'),
#  (0.52294624, 'Village, The (2004)'),
#  (0.95922738, 'Victor/Victoria (1982)'),
#  (1.1954842, 'Road Warrior, The (Mad Max 2) (1981)'),
#  (0.46184689, "Pee-wee's Big Adventure (1985)"),
#  (0.28685734, 'U-571 (2000)'),
#  (1.1351699, 'Life Aquatic with Steve Zissou, The (2004)'),
#  (0.44405779, 'Bodyguard, The (1992)'),
#  (0.73963898, 'Star Wars: Episode VII - The Force Awakens (2015)'),
#  (1.2795969, 'Robin Hood (1973)'),
#  (0.96708596, 'Big Daddy (1999)'),
#  (0.53888416, 'Sex, Lies, and Videotape (1989)'),
#  (1.7134796, 'On the Waterfront (1954)'),
#  (1.3280146, 'Malcolm X (1992)'),
#  (0.30885392, 'Sgt. Bilko (1996)'),
#  (0.94725758, 'Gosford Park (2001)'),
#  (0.79798698, "White Men Can't Jump (1992)"),
#  (0.75738436, 'What About Bob? (1991)'),
#  (0.7563026, 'Boiler Room (2000)'),
#  (1.2130163, 'Out of Sight (1998)'),
#  (1.4310018, 'Dog Day Afternoon (1975)'),
#  (1.3993456, 'Being There (1979)'),
#  (1.3215258, 'My Left Foot (1989)'),
#  (-0.29358962, 'Anaconda (1997)'),
#  (1.2647799, 'Crimes and Misdemeanors (1989)'),
#  (1.5765913, 'Moon (2009)'),
#  (0.96588671, 'City Slickers (1991)'),
#  (0.82196611, 'Benny & Joon (1993)'),
#  (0.48040572, 'Final Destination (2000)'),
#  (1.1401931, 'Whiplash (2014)'),
#  (0.94635767, 'Dark Crystal, The (1982)'),
#  (0.62539595, "Logan's Run (1976)"),
#  (1.2758435, 'Inside Man (2006)'),
#  (1.0821775, 'Return of the Pink Panther, The (1975)'),
#  (1.0062262, 'On Golden Pond (1981)'),
#  (1.2514504, 'Ever After: A Cinderella Story (1998)'),
#  (0.41642052, 'Poseidon Adventure, The (1972)'),
#  (1.1482208, 'Mean Girls (2004)'),
#  (0.53694606, 'Patch Adams (1998)'),
#  (0.9934237, 'River Runs Through It, A (1992)'),
#  (0.80573303, 'Walk in the Clouds, A (1995)'),
#  (0.90461785, 'Tarzan (1999)'),
#  (0.82957125, 'Hellboy (2004)'),
#  (0.17019767, 'Daredevil (2003)'),
#  (1.0386124, 'Phone Booth (2002)'),
#  (1.0473206, 'Wallace & Gromit in The Curse of the Were-Rabbit (2005)'),
#  (0.78443962, 'Madagascar (2005)'),
#  (1.0755372, 'Elephant Man, The (1980)'),
#  (0.215312, 'Escape from L.A. (1996)'),
#  (0.94011754, 'Young Guns (1988)'),
#  (1.2993151, 'X-Men: First Class (2011)'),
#  (-0.30162254, 'Godzilla (1998)'),
#  (0.96222615, 'Fletch (1985)'),
#  (0.86672735, "Knight's Tale, A (2001)"),
#  (1.1859474, 'Bound (1996)'),
#  (1.6062794, 'Night of the Living Dead (1968)'),
#  (1.3723893, 'Glengarry Glen Ross (1992)'),
#  (0.81261837, "Monster's Ball (2001)"),
#  (0.29571843, 'Down Periscope (1996)'),
#  (0.91932189, 'Elf (2003)'),
#  (0.15154812, 'Dr. Dolittle (1998)'),
#  (1.5686737, 'Ghost in the Shell (Kôkaku kidôtai) (1995)'),
#  (1.2069604, 'Hoosiers (a.k.a. Best Shot) (1986)'),
#  (1.3538178, 'Intouchables (2011)'),
#  (1.2291853, "Miller's Crossing (1990)"),
#  (0.58558798, 'Beach, The (2000)'),
#  (0.073091328, 'Scream 3 (2000)'),
#  (1.5514377, 'Charade (1963)'),
#  (1.5578648, "Howl's Moving Castle (Hauru no ugoku shiro) (2004)"),
#  (0.34315854, 'Stuart Little (1999)'),
#  (0.27101594, 'Dick Tracy (1990)'),
#  (0.8921845, 'Naked Gun 2 1/2: The Smell of Fear, The (1991)'),
#  (0.16026001, "Weekend at Bernie's (1989)"),
#  (0.4943094, 'Coyote Ugly (2000)'),
#  (-0.0056858184, 'Karate Kid, Part II, The (1986)'),
#  (1.3096967, 'Boyz N the Hood (1991)'),
#  (0.12028272, 'G.I. Jane (1997)'),
#  (0.2175696, 'Lawnmower Man, The (1992)'),
#  (0.85250151, 'Muppet Treasure Island (1996)'),
#  (0.65028274, 'Secret of NIMH, The (1982)'),
#  (1.5321906, 'Serpico (1973)'),
#  (1.2083703, 'Good Night, and Good Luck. (2005)'),
#  (1.2141178, 'Red Dragon (2002)'),
#  (0.20819023, 'Jaws 2 (1978)'),
#  (0.64990544, "Mary Shelley's Frankenstein (Frankenstein) (1994)"),
#  (1.3149495, 'Drugstore Cowboy (1989)'),
#  (1.1280878, '25th Hour (2002)'),
#  (0.50921738, 'Mulholland Falls (1996)'),
#  (0.62987775, 'Whole Nine Yards, The (2000)'),
#  (1.193401, 'Secrets & Lies (1996)'),
#  (0.91093689, 'Pitch Black (2000)'),
#  (0.68289864, 'Rush Hour 2 (2001)'),
#  (1.246093, 'Finding Forrester (2000)'),
#  (1.0663581, 'Watchmen (2009)'),
#  (0.79326135, 'Up in the Air (2009)'),
#  (1.2564774, 'Moonrise Kingdom (2012)'),
#  (1.0558274, 'Devil in a Blue Dress (1995)'),
#  (0.87892526, 'American Tail, An (1986)'),
#  (1.5481755, 'Roman Holiday (1953)'),
#  (1.406054, 'Scott Pilgrim vs. the World (2010)'),
#  (0.93239295, 'Halloween (1978)'),
#  (1.1090597, 'Edge of Tomorrow (2014)'),
#  (1.1152424, 'Ex Machina (2015)'),
#  (1.6406145, 'My Neighbor Totoro (Tonari no Totoro) (1988)'),
#  (1.3322417, 'Short Cuts (1993)'),
#  (0.82247126, 'Hackers (1995)'),
#  (0.98946977, 'Sword in the Stone, The (1963)'),
#  (1.1713526, 'Motorcycle Diaries, The (Diarios de motocicleta) (2004)'),
#  (0.0024258357, 'Airheads (1994)'),
#  (1.4795796, 'Hurt Locker, The (2008)'),
#  (0.71175659, 'Waterboy, The (1998)'),
#  (1.0844011, 'Sherlock Holmes: A Game of Shadows (2011)'),
#  (0.80457115, 'Four Rooms (1995)'),
#  (0.83786929, 'Brothers McMullen, The (1995)'),
#  (0.66438454, 'First Wives Club, The (1996)'),
#  (0.17770237, 'Juror, The (1996)'),
#  (1.4204811, "Sophie's Choice (1982)"),
#  (1.780356, 'Ran (1985)'),
#  (0.98866266, 'Spy Game (2001)'),
#  (1.2623237, 'Dial M for Murder (1954)'),
#  (1.3559198, 'Metropolis (1927)'),
#  (1.179895, 'Laura (1944)'),
#  (0.89194423, 'Insomnia (2002)'),
#  (-0.42447686, 'Lost in Space (1998)'),
#  (1.6134791, 'His Girl Friday (1940)'),
#  (1.6175518, 'And Your Mother Too (Y tu mamá también) (2001)'),
#  (0.76200855, 'What Lies Beneath (2000)'),
#  (1.0909625, 'Battle Royale (Batoru rowaiaru) (2000)'),
#  (1.6070038, 'There Will Be Blood (2007)'),
#  (1.3427385, 'Sliding Doors (1998)'),
#  (-0.0053642821, 'Tank Girl (1995)'),
#  (0.66641128, 'The Hunger Games: Catching Fire (2013)'),
#  (0.11382873, 'Wedding Planner, The (2001)'),
#  (-0.15680714, 'Island of Dr. Moreau, The (1996)'),
#  (0.76119578, 'Airplane II: The Sequel (1982)'),
#  (0.76845574, 'Cars (2006)'),
#  (0.89387536, 'Age of Innocence, The (1993)'),
#  (1.3343064, 'Lucky Number Slevin (2006)'),
#  ...]

# %%
#same thing but for the embeddings
get_movie_emb = Model(movie_in, m)
movie_emb = np.squeeze(get_movie_emb.predict([topMovies]))
movie_emb.shape
# Out:
# (2000, 50)

# %%
#reduce dimensionality with PCA
from sklearn.decomposition import PCA
pca = PCA(n_components=3)
movie_pca = pca.fit(movie_emb.T).components_

# %%
#the first component seems to be "lighthearted"
fac0 = movie_pca[0]
movie_comp = [(f, movie_names[movies[i]]) for f,i in zip(fac0, topMovies)]
sorted(movie_comp, reverse=True)[:10]
# Out:
# [(0.11966001, 'Independence Day (a.k.a. ID4) (1996)'),
#  (0.10379191, 'Armageddon (1998)'),
#  (0.068023458, 'Shrek (2001)'),
#  (0.06713897, 'Stargate (1994)'),
#  (0.065725878, 'Star Wars: Episode I - The Phantom Menace (1999)'),
#  (0.065280564, 'Pearl Harbor (2001)'),
#  (0.063906938, 'Pay It Forward (2000)'),
#  (0.061858326, 'Con Air (1997)'),
#  (0.061536286, 'Ace Ventura: Pet Detective (1994)'),
#  (0.060085941, 'Three Musketeers, The (1993)')]

# %%
sorted(movie_comp, reverse=True)[-10:]
# Out:
# [(-0.074374177, 'Leaving Las Vegas (1995)'),
#  (-0.075018689, 'Godfather, The (1972)'),
#  (-0.075442955, 'Sideways (2004)'),
#  (-0.077937499, 'Blade Runner (1982)'),
#  (-0.083713144, '2001: A Space Odyssey (1968)'),
#  (-0.089220598, 'Fargo (1996)'),
#  (-0.0892848, 'Big Lebowski, The (1998)'),
#  (-0.090143129, 'Clockwork Orange, A (1971)'),
#  (-0.093870796, 'Taxi Driver (1976)'),
#  (-0.11106043, 'Pulp Fiction (1994)')]

# %%
#the second component seems to be "serious epic"
fac1 = movie_pca[1]
movie_comp = [(f, movie_names[movies[i]]) for f,i in zip(fac1, topMovies)]
sorted(movie_comp, reverse=True)[:10]
# Out:
# [(0.16545823, 'Lord of the Rings: The Two Towers, The (2002)'),
#  (0.15565476, 'Lord of the Rings: The Fellowship of the Ring, The (2001)'),
#  (0.13412994, 'Lord of the Rings: The Return of the King, The (2003)'),
#  (0.13293108, 'Matrix, The (1999)'),
#  (0.12311188, 'Jurassic Park (1993)'),
#  (0.11891862,
#   'Raiders of the Lost Ark (Indiana Jones and the Raiders of the Lost Ark) (1981)'),
#  (0.11722182, 'Gladiator (2000)'),
#  (0.11457396, 'Star Wars: Episode V - The Empire Strikes Back (1980)'),
#  (0.11172211, 'Star Wars: Episode VI - Return of the Jedi (1983)'),
#  (0.1085334, 'Dances with Wolves (1990)')]

# %%
sorted(movie_comp, reverse=True)[-10:]
# Out:
# [(-0.043559909, 'Hoop Dreams (1994)'),
#  (-0.044469871, 'Judge Dredd (1995)'),
#  (-0.044979084, 'Four Weddings and a Funeral (1994)'),
#  (-0.045300372, 'Ransom (1996)'),
#  (-0.045804527, 'Alien: Resurrection (1997)'),
#  (-0.047873728, 'Lives of Others, The (Das leben der Anderen) (2006)'),
#  (-0.050127681, 'Room with a View, A (1986)'),
#  (-0.051874865, 'Island of Dr. Moreau, The (1996)'),
#  (-0.054059375, 'Annie Hall (1977)'),
#  (-0.054278318, 'Little Miss Sunshine (2006)')]

# %%
#the third component seems to be "violent/adult"
fac2 = movie_pca[2]
movie_comp = [(f, movie_names[movies[i]]) for f,i in zip(fac2, topMovies)]
sorted(movie_comp, reverse=True)[:10]
# Out:
# [(0.099625774, 'Seven (a.k.a. Se7en) (1995)'),
#  (0.097437553, 'Natural Born Killers (1994)'),
#  (0.089570835, 'Stargate (1994)'),
#  (0.081196181, 'Happy Gilmore (1996)'),
#  (0.076776825, 'American Psycho (2000)'),
#  (0.076167397, 'Dogma (1999)'),
#  (0.075688913, 'Die Hard: With a Vengeance (1995)'),
#  (0.075214759, 'Eyes Wide Shut (1999)'),
#  (0.072266996, 'Armageddon (1998)'),
#  (0.070500925,
#   'Léon: The Professional (a.k.a. The Professional) (Léon) (1994)')]

# %%
sorted(movie_comp, reverse=True)[-10:]
# Out:
# [(-0.072909266, "Bug's Life, A (1998)"),
#  (-0.075818278, 'Aladdin (1992)'),
#  (-0.076405525, 'Grease (1978)'),
#  (-0.076853089, 'Chicken Run (2000)'),
#  (-0.081125103, 'Dances with Wolves (1990)'),
#  (-0.082340948, 'Apollo 13 (1995)'),
#  (-0.083156765, 'Sound of Music, The (1965)'),
#  (-0.096660517, 'Babe (1995)'),
#  (-0.098518029, 'Sling Blade (1996)'),
#  (-0.10521671, 'Beauty and the Beast (1991)')]

# %% [markdown]
# ## Nueral net

# %%
#often easier and more accurate to use a NN instead of special built architecture (like a dot product)
user_in, u = embedding_input('user_in', n_users, n_factors, 1e-4)
movie_in, m = embedding_input('movie_in', n_movies, n_factors, 1e-4)

x = merge([u, m], mode='concat')
x = Flatten()(x)
x = Dropout(0.3)(x)
x = Dense(70, activation='relu')(x)
x = Dropout(0.75)(x)
x = Dense(1)(x)
nn = Model([user_in, movie_in], x)
nn.compile(Adam(0.001), loss='mse')

# %%
nn.fit([trn.userId, trn.movieId], trn.rating, batch_size=64, nb_epoch=8, 
          validation_data=([val.userId, val.movieId], val.rating))
# Out:
# Train on 80084 samples, validate on 19920 samples
# Epoch 1/8
# 80084/80084 [==============================] - 8s - loss: 2.4446 - val_loss: 0.9013
# Epoch 2/8
# 80084/80084 [==============================] - 7s - loss: 1.4347 - val_loss: 0.8785
# Epoch 3/8
# 80084/80084 [==============================] - 7s - loss: 1.2158 - val_loss: 0.8576
# Epoch 4/8
# 80084/80084 [==============================] - 7s - loss: 1.0368 - val_loss: 0.8532
# Epoch 5/8
# 80084/80084 [==============================] - 7s - loss: 0.9145 - val_loss: 0.8433
# Epoch 6/8
# 80084/80084 [==============================] - 7s - loss: 0.8516 - val_loss: 0.8378
# Epoch 7/8
# 80084/80084 [==============================] - 7s - loss: 0.8189 - val_loss: 0.8376
# Epoch 8/8
# 80084/80084 [==============================] - 7s - loss: 0.8071 - val_loss: 0.8390
